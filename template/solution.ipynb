# %% [markdown]
# # 1. Problem Information
# - **Name:** [**{Problem Name}**](https://example.com/)
# - **Date:** 12/02/2026
# - **Type:** (Regression / Binary Classification / Multi-class / NLP / CV)

# %% [markdown]
# # 2. Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 3. Data preparation

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")
print(train.shape)
train.head(5)

# %%
train.describe().round(3)

# %% [markdown]
# # 4. Models

# %% [markdown]
# # 5. Submission

# %%
df_task1 = pd.DataFrame({
    "subtaskID": [0],
    "datapointID": [0],
    "answer": [0]
})

df_task2 = pd.DataFrame({
    "subtaskID": [1],
    "datapointID": [1],
    "answer": [1],
})

submission = pd.concat([df_task1, df_task2])
submission.head()

# %%
submission.to_csv("submission.csv", index=False)
